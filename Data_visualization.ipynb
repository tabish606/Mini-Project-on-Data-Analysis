# %%
import pandas as pd

# %%
cd ml-20m/
# Out:
# C:\Users\Tabish\python\ml-20m

# %%
tags = pd.read_csv('./tags.csv')

# %%
tags.head()
# Out:
#    userId  movieId            tag   timestamp
# 0      18     4141    Mark Waters  1240597180
# 1      65      208      dark hero  1368150078
# 2      65      353      dark hero  1368150079
# 3      65      521  noir thriller  1368149983
# 4      65      592      dark hero  1368150078

# %%
tags.shape
# Out:
# (465564, 4)

# %%
# %matplotlib inline

# %%
tags.hist(column = 'userId' ,figsize = (15,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000000009704E80>]],
#       dtype=object)

# %%
tags.boxplot(column = 'userId', figsize = (15,20))

# %% [markdown]
# <h1 style="font-size:2em;color:#2467C0">Slicing Out Columns</h1>

# %%
tags['tag'].head()
# Out:
# 0      Mark Waters
# 1        dark hero
# 2        dark hero
# 3    noir thriller
# 4        dark hero
# Name: tag, dtype: object

# %%
movies = pd.read_csv('./movies.csv')

# %%
movies[['title','genres']].head()
# Out:
#                                 title  \
# 0                    Toy Story (1995)
# 1                      Jumanji (1995)
# 2             Grumpier Old Men (1995)
# 3            Waiting to Exhale (1995)
# 4  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
tags[-10 :] # gives last ten rows
# Out:
#         userId  movieId                               tag   timestamp
# 465554  138446     3489                visually appealing  1358983822
# 465555  138446     7045                   family friendly  1358983660
# 465556  138446     7045  Scary Movies To See on Halloween  1358983660
# 465557  138446     7164                         Peter Pan  1358983855
# 465558  138446     7164                visually appealing  1358983855
# 465559  138446    55999                           dragged  1358983772
# 465560  138446    55999                     Jason Bateman  1358983778
# 465561  138446    55999                            quirky  1358983778
# 465562  138446    55999                               sad  1358983772
# 465563  138472      923                     rise to power  1194037967

# %%
tags_count = tags['tag'].value_counts()
tags_count[:10]
# Out:
# sci-fi             3384
# based on a book    3281
# atmospheric        2917
# comedy             2779
# action             2657
# surreal            2427
# BD-R               2334
# twist ending       2323
# funny              2072
# dystopia           1991
# Name: tag, dtype: int64

# %%
tags_count[:10].plot(kind = "bar", figsize = (15,10))

# %%
high_tags_count = tags_count >= 2000
tags_count[high_tags_count][0:20]
# Out:
# sci-fi             3384
# based on a book    3281
# atmospheric        2917
# comedy             2779
# action             2657
# surreal            2427
# BD-R               2334
# twist ending       2323
# funny              2072
# Name: tag, dtype: int64

# %%
is_animation = movies['genres'].str.contains('Animation')
movies[is_animation][5:15]
# Out:
#      movieId                                       title  \
# 310      313                   Swan Princess, The (1994)
# 360      364                       Lion King, The (1994)
# 388      392  Secret Adventures of Tom Thumb, The (1993)
# 547      551      Nightmare Before Christmas, The (1993)
# 553      558                      Pagemaster, The (1994)
# 582      588                              Aladdin (1992)
# 588      594      Snow White and the Seven Dwarfs (1937)
# 589      595                 Beauty and the Beast (1991)
# 590      596                            Pinocchio (1940)
# 604      610                          Heavy Metal (1981)
#
#                                               genres
# 310                               Animation|Children
# 360  Adventure|Animation|Children|Drama|Musical|IMAX
# 388                              Adventure|Animation
# 547               Animation|Children|Fantasy|Musical
# 553      Action|Adventure|Animation|Children|Fantasy
# ...

# %%
movies[is_animation].head(15)
# Out:
#      movieId                                       title  \
# 0          1                            Toy Story (1995)
# 12        13                                Balto (1995)
# 47        48                           Pocahontas (1995)
# 236      239                       Goofy Movie, A (1995)
# 241      244                     Gumby: The Movie (1995)
# 310      313                   Swan Princess, The (1994)
# 360      364                       Lion King, The (1994)
# 388      392  Secret Adventures of Tom Thumb, The (1993)
# 547      551      Nightmare Before Christmas, The (1993)
# 553      558                      Pagemaster, The (1994)
# 582      588                              Aladdin (1992)
# 588      594      Snow White and the Seven Dwarfs (1937)
# 589      595                 Beauty and the Beast (1991)
# 590      596                            Pinocchio (1940)
# 604      610                          Heavy Metal (1981)
#
# ...

# %%
is_title= movies['title'].str.contains('2013') & movies['genres'].str.contains('Action')
movies[is_title].head(100)
# Out:
#        movieId                                              title  \
# 20280    99728                              Gangster Squad (2013)
# 20307    99813     Batman: The Dark Knight Returns, Part 2 (2013)
# 20337    99910                             Last Stand, The (2013)
# 20413   100163              Hansel & Gretel: Witch Hunters (2013)
# 20523   100498                     Good Day to Die Hard, A (2013)
# 20578   100737                                      Snitch (2013)
# 20615   101076                       G.I. Joe: Retaliation (2013)
# 20623   101112                   Oz the Great and Powerful (2013)
# 20628   101137                               Dead Man Down (2013)
# 20698   101362                          Olympus Has Fallen (2013)
# 20747   101577                                   Host, The (2013)
# 20803   101761                        Welcome to the Punch (2013)
# 20827   101864                                    Oblivion (2013)
# ...

# %% [markdown]
# # Group by and Aggregate

# %%
av_movies = movies[['movieId','title']].groupby('movieId').count()
av_movies.tail()
# Out:
#          title
# movieId
# 131254       1
# 131256       1
# 131258       1
# 131260       1
# 131262       1

# %%
tags.head()
# Out:
#    userId  movieId            tag   timestamp
# 0      18     4141    Mark Waters  1240597180
# 1      65      208      dark hero  1368150078
# 2      65      353      dark hero  1368150079
# 3      65      521  noir thriller  1368149983
# 4      65      592      dark hero  1368150078

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %% [markdown]
# <h1 style="font-size:2em;color:#2467C0">Merge Dataframes</h1>

# %%
import pandas as pd

# %%
cd ml-20m/
# Out:
# C:\Users\Tabish\python\ml-20m

# %%
tag = pd.read_csv("./tags.csv")

# %%
movie = pd.read_csv("./movies.csv")

# %%
t = movie.merge(tag, on  = 'movieId',how = 'inner')
t.head()
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 4        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#    userId                                     tag   timestamp
# 0    1644                                 Watched  1417736680
# 1    1741                      computer animation  1183903155
# 2    1741                 Disney animated feature  1183933307
# 3    1741                         Pixar animation  1183934770
# 4    1741  T̩a Leoni does not star in this movie  1245093573

# %%
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
   ...:                     'B': ['B0', 'B1', 'B2', 'B3'],
   ...:                     'C': ['C0', 'C1', 'C2', 'C3'],
   ...:                     'D': ['D0', 'D1', 'D2', 'D3']},
   ...:                    index=[0, 1, 2, 3])
df2 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'],
   ...:                     'B': ['B4', 'B5', 'B6', 'B7'],
   ...:                     'C': ['C4', 'C5', 'C6', 'C7'],
   ...:                     'D': ['D4', 'D5', 'D6', 'D7']},
   ...:                    index=[4, 5, 6, 7])
df3 = pd.DataFrame({'A': ['A8', 'A9', 'A10', 'A11'],
   ...:                     'B': ['B8', 'B9', 'B10', 'B11'],
   ...:                     'C': ['C8', 'C9', 'C10', 'C11'],
   ...:                     'D': ['D8', 'D9', 'D10', 'D11']},
   ...:                    index=[8, 9, 10, 11])
   ...:
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-1e8dfe35750c> in <module>()
# ----> 1 df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
#       2                     'B': ['B0', 'B1', 'B2', 'B3'],
#       3                     'C': ['C0', 'C1', 'C2', 'C3'],
#       4                     'D': ['D0', 'D1', 'D2', 'D3']},
#       5                    index=[0, 1, 2, 3])
#
# NameError: name 'pd' is not defined

# %%
frames = [df1,df2,df3]

# %%
pd.concat(frames)
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-00cf07b74dcd> in <module>()
# ----> 1 df
#
# NameError: name 'df' is not defined

# %% [markdown]
# <p style="font-family: Arial; font-size:1.75em;color:#2462C0; font-style:bold"><br>
#
#
# Combine aggreagation, merging, and filters to get useful analytics
# </p>
